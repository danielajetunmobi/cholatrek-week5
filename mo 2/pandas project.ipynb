# %%
import pandas as pd

# %% [markdown]
# 1 city with best customer

# %%
data1=pd.read_csv('C:/Users/user/Desktop/chinook Music store/Invoice.csv')
data1
# Out:
#      InvoiceId  CustomerId  InvoiceDate  \
# 0            1           2          NaN
# 1            2           4          NaN
# 2            3           8          NaN
# 3            4          14          NaN
# 4            5          23          NaN
# ..         ...         ...          ...
# 407        408          25          NaN
# 408        409          29          NaN
# 409        410          35          NaN
# 410        411          44          NaN
# 411        412          58          NaN
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart          NaN
# 1                            Ullevålsveien 14        Oslo          NaN
# 2                             Grétrystraat 63    Brussels          NaN
# 3                              8210 111 ST NW    Edmonton           AB
# 4                             69 Salem Street      Boston           MA
# ...

# %%
data=pd.read_csv('C:/Users/user/Desktop/chinook Music store/InvoiceLine.csv')
data
# Out:
#       InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0                 1          1        2       0.99         1
# 1                 2          1        4       0.99         1
# 2                 3          2        6       0.99         1
# 3                 4          2        8       0.99         1
# 4                 5          2       10       0.99         1
# ...             ...        ...      ...        ...       ...
# 2235           2236        411     3136       0.99         1
# 2236           2237        411     3145       0.99         1
# 2237           2238        411     3154       0.99         1
# 2238           2239        411     3163       0.99         1
# 2239           2240        412     3177       1.99         1
#
# [2240 rows x 5 columns]

# %%
data2=pd.merge(data,data1,how='outer',on='InvoiceId')
data2
# Out:
#       InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity  CustomerId  \
# 0                 1          1        2       0.99         1           2
# 1                 2          1        4       0.99         1           2
# 2                 3          2        6       0.99         1           4
# 3                 4          2        8       0.99         1           4
# 4                 5          2       10       0.99         1           4
# ...             ...        ...      ...        ...       ...         ...
# 2235           2236        411     3136       0.99         1          44
# 2236           2237        411     3145       0.99         1          44
# 2237           2238        411     3154       0.99         1          44
# 2238           2239        411     3163       0.99         1          44
# 2239           2240        412     3177       1.99         1          58
#
#       InvoiceDate           BillingAddress BillingCity BillingState  \
# ...

# %%
data2['BillingCity'].isna().sum()
# Out:
# 0

# %%
total=data2.groupby('BillingCity')

# %%
t=total['Total'].sum()
t.idxmax()
# Out:
# 'Prague'

# %% [markdown]
# city with best customer is prague

# %% [markdown]
# (2) country with most invoices

# %%
country=data2.groupby('BillingCountry')

# %%
t=country['InvoiceId'].sum()
t.idxmax()
# Out:
# 'USA'

# %% [markdown]
# country with most invoices is USA

# %% [markdown]
# 3 customer that spend the most

# %%
read=pd.read_csv('C:/Users/user/Desktop/chinook Music store/Customer.csv')

# %%
read1=pd.merge(data2,read,how='outer', on='CustomerId')
read1
# Out:
#       InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity  CustomerId  \
# 0                 1          1        2       0.99         1           2
# 1                 2          1        4       0.99         1           2
# 2                60         12      331       0.99         1           2
# 3                61         12      340       0.99         1           2
# 4                62         12      349       0.99         1           2
# ...             ...        ...      ...        ...       ...         ...
# 2235           2221        410     3013       0.99         1          35
# 2236           2222        410     3019       0.99         1          35
# 2237           2223        410     3025       0.99         1          35
# 2238           2224        410     3031       0.99         1          35
# 2239           2225        410     3037       0.99         1          35
#
#       InvoiceDate                            BillingAddress BillingCity  \
# ...

# %%
read2=read1.groupby('CustomerId')

# %%
r=read2['Total'].sum()

# %%
print(r.idxmax())
# Out:
# 6

# %% [markdown]
# the best customer is Helena HolÃ½

# %% [markdown]
# the Email firsname lastname of rock music listener

# %%
ted=pd.read_csv('C:/Users/user/Desktop/chinook Music store/Genre.csv')

# %%
ted1=pd.read_csv('C:/Users/user/Desktop/chinook Music store/Track.csv')

# %%
ted2=pd.merge(ted,ted1,how='left',on='GenreId')
ted2
# Out:
#       GenreId     Name_x  TrackId  \
# 0           1       Rock        1
# 1           1       Rock        2
# 2           1       Rock        3
# 3           1       Rock        4
# 4           1       Rock        5
# ...       ...        ...      ...
# 3498       24  Classical     3499
# 3499       24  Classical     3500
# 3500       24  Classical     3501
# 3501       24  Classical     3502
# 3502       25      Opera     3451
#
#                                                  Name_y  AlbumId  MediaTypeId  \
# 0               For Those About To Rock (We Salute You)        1            1
# 1                                     Balls to the Wall        2            2
# 2                                       Fast As a Shark        3            2
# 3                                     Restless and Wild        3            2
# 4                                  Princess of the Dawn        3            2
# ...                                                 ...      ...          ...
# ...

# %%
best2=pd.merge(read1,ted2, how='left',on='TrackId')
best2
# Out:
#       InvoiceLineId  InvoiceId  TrackId  UnitPrice_x  Quantity  CustomerId  \
# 0                 1          1        2         0.99         1           2
# 1                 2          1        4         0.99         1           2
# 2                60         12      331         0.99         1           2
# 3                61         12      340         0.99         1           2
# 4                62         12      349         0.99         1           2
# ...             ...        ...      ...          ...       ...         ...
# 2235           2221        410     3013         0.99         1          35
# 2236           2222        410     3019         0.99         1          35
# 2237           2223        410     3025         0.99         1          35
# 2238           2224        410     3031         0.99         1          35
# 2239           2225        410     3037         0.99         1          35
#
# ...

# %%
rock1=best2.filter(items=['FirstName','LastName','Email','CustomerId','Name_x'=='Rock'])
rock2=rock1.set_index('Email').sort_values(by='FirstName')
rock2.drop_duplicates().dropna()
# Out:
#                                FirstName      LastName  CustomerId
# Email
# aaronmitchell@yahoo.ca             Aaron      Mitchell        32.0
# alero@uol.com.br               Alexandre         Rocha        11.0
# astrid.gruber@apple.at            Astrid        Gruber         7.0
# bjorn.hansen@yahoo.no              Bjørn        Hansen         4.0
# camille.bernard@yahoo.fr         Camille       Bernard        39.0
# daan_peeters@apple.be               Daan       Peeters         8.0
# dmiller@comcast.com                  Dan        Miller        20.0
# diego.gutierrez@yahoo.ar           Diego     Gutiérrez        56.0
# dominiquelefebvre@gmail.com    Dominique      Lefebvre        40.0
# eduardo@woodstock.com.br         Eduardo       Martins        10.0
# edfrancis@yachoo.ca               Edward       Francis        30.0
# ellie.sullivan@shaw.ca             Ellie      Sullivan        33.0
# emma_jones@hotmail.com              Emma         Jones        52.0
# ...

# %% [markdown]
# 5 most pupolar genre in each country

# %%
rock=best2.groupby(['BillingCountry'])
rock['Name_x'].max()
# Out:
# BillingCountry
# Argentina               Soundtrack
# Australia                     Rock
# Austria                   TV Shows
# Belgium                       Rock
# Brazil                       World
# Canada                       World
# Chile                     TV Shows
# Czech Republic            TV Shows
# Denmark                       Rock
# Finland           Sci Fi & Fantasy
# France                    TV Shows
# Germany                   TV Shows
# Hungary                   TV Shows
# India                     TV Shows
# Ireland                   TV Shows
# Italy                         Rock
# Netherlands       Sci Fi & Fantasy
# Norway                       World
# Poland                        Rock
# Portugal                     World
# Spain                         Rock
# Sweden                       World
# USA                       TV Shows
# United Kingdom               World
# Name: Name_x, dtype: object
